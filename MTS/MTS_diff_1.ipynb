# %%
""" 
Created on FRI JAN 18 2019
 
MTS Program that graphs difference in mahalanobis distances, as well as an MTS 
 
@author: Taehee 
""" 

from __future__ import print_function 
import numpy as np 
import matplotlib.pyplot as plt 
import copy 
import math
import csv
import pandas as pd
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
OKdata=pd.read_csv('C:/Users/mando/Desktop/ssd/diff.csv',encoding='utf-8') # SAA8
OKdata=OKdata.iloc[:,2:]

# %%
OKdata
# Out:
#        col_kgf  curl_kgf  torque_time    rpm  height    end  h_e  diff_eval
# 0         1644      2038          0.4    4.1   134.3  143.8 -9.5       1.36
# 1         1694      2069          0.6    3.7   134.3  143.9 -9.6       1.42
# 2         1619      2063          0.7    4.0   134.0  143.6 -9.6       1.43
# 3         1706      2206          0.7    3.9   134.2  143.7 -9.5       1.39
# 4         1644      2050          0.7    3.7   134.2  143.9 -9.7       1.40
# 5         1731      2044          0.6  104.3   134.2  143.7 -9.5       1.35
# 6         1706      2088          0.4    3.7   134.4  143.9 -9.5       1.38
# 7         1688      2069          0.7    4.1   134.3  143.6 -9.3       1.40
# 8         1688      2131          0.8    4.1   134.4  144.0 -9.6       1.34
# 9         1663      2138          0.6  105.9   134.5  144.2 -9.7       1.31
# 10        1663      2088          0.7    3.9   134.3  143.8 -9.5       1.37
# ...

# %%
train_set,test_set = train_test_split(OKdata,test_size=0.3,random_state=42)

# %%
results = smf.ols('diff_eval ~ height+col_kgf+curl_kgf+h_e', data=OKdata).fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              diff_eval   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     1100.
# Date:                Fri, 25 Jan 2019   Prob (F-statistic):               0.00
# Time:                        14:59:36   Log-Likelihood:             1.1627e+05
# No. Observations:               81028   AIC:                        -2.325e+05
# Df Residuals:                   81023   BIC:                        -2.325e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.4660      0.022    113.744      0.000       2.423       2.508
# ...

# %%
results = smf.ols('diff_eval ~ height+col_kgf+curl_kgf+h_e+rpm+torque_time', data=OKdata).fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              diff_eval   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     846.5
# Date:                Fri, 25 Jan 2019   Prob (F-statistic):               0.00
# Time:                        14:59:42   Log-Likelihood:             1.1659e+05
# No. Observations:               81028   AIC:                        -2.332e+05
# Df Residuals:                   81021   BIC:                        -2.331e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.4051      0.022    110.689      0.000       2.362       2.448
# ...
